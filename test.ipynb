# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow и tf.keras
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image 

# Вспомогательные библиотеки
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.15.0

# %%
new_model = keras.models.load_model('my_model.h5')
new_model.summary()
# Out:
# WARNING:tensorflow:Sequential models without an `input_shape` passed to the first layer cannot reload their optimizer state. As a result, your model isstarting with a freshly initialized optimizer.
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           multiple                  640
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_13 (Conv2D)           multiple                  73856
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_14 (Conv2D)           multiple                  295168
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_7 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_22 (Dense)             multiple                  32896
# _________________________________________________________________
# dropout_12 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_23 (Dense)             multiple                  8256
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_24 (Dense)             multiple                  2080
# _________________________________________________________________
# dropout_14 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  330
# =================================================================
# Total params: 413,226
# Trainable params: 413,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
img_patch="images/8.jpg"
img=image.load_img(img_patch,target_size=(28,28))
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
x=image.img_to_array(img)
x/=255
x=np.expand_dims(x,axis=0)

# %%
classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print (x.shape)
print (len(x))
# Out:
# (1, 28, 28, 3)
# 1

# %%
x=x.reshape(3,28,28,1)

# %%
img = x[1]
print(img.shape)
# Out:
# (28, 28, 1)

# %%
img = (np.expand_dims(img,0))
print(img.shape)
# Out:
# (1, 28, 28, 1)

# %%
predictions = new_model.predict(img)
predictions[0]
# Out:
# array([5.0257500e-02, 4.9990062e-03, 1.5957108e-02, 6.7226584e-03,
#        1.1833978e-02, 4.7626435e-03, 2.2496639e-01, 2.7848411e-04,
#        6.8012613e-01, 9.6080315e-05], dtype=float32)

# %%
predictions=np.argmax(predictions[0])
print(classes[predictions])
# Out:
# Bag
